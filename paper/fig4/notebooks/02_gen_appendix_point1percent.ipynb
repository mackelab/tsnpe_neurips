# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from sbibm.visualisation import fig_metric
import matplotlib.pyplot as plt
import matplotlib as mpl
import scipy.stats as st
import numpy as np
import seaborn as sns
from typing import Any, Dict, List, Optional

from paper.utils import fig_metric_mpl, extract_diagnostic, fig_diagnostic

# %%
df = pd.read_pickle("../../results/benchmark_fig/results_thr_point1percent.pkl")

# %%
len(df)
# Out:
# 180

# %%
df1 = pd.read_csv("../../results/sbibm_results.csv")

# %%
npe_results = df1.query("algorithm == 'NPE'")
snpe_results = df1.query("algorithm == 'SNPE'")

# %%
all_results = pd.concat([df, npe_results, snpe_results])

# %%
results_subset = all_results.query("task == 'gaussian_linear'")
with mpl.rc_context(fname="../../.matplotlibrc"):
    fig = fig_metric_mpl(results_subset, metric="C2ST", task_name="Gaussian Linear", title=False, xlabel=False)
    plt.savefig("../svg/panel_appendix_1_a.svg", transparent=True)

# %%
results_subset = all_results.query("task == 'slcp'")
with mpl.rc_context(fname="../../.matplotlibrc"):
    fig = fig_metric_mpl(results_subset, metric="C2ST", task_name="SLCP", title=False, xlabel=False)
    plt.savefig("../svg/panel_appendix_1_b.svg", transparent=True)

# %%
results_subset = all_results.query("task == 'sir'")
with mpl.rc_context(fname="../../.matplotlibrc"):
    fig = fig_metric_mpl(results_subset, metric="C2ST", task_name="SIR", title=False, xlabel=False)
    plt.savefig("../svg/panel_appendix_1_c.svg", transparent=True)

# %%
results_subset = all_results.query("task == 'two_moons'")
with mpl.rc_context(fname="../../.matplotlibrc"):
    fig = fig_metric_mpl(results_subset, metric="C2ST", task_name="Two Moons", title=False, xlabel=False)
    plt.savefig("../svg/panel_appendix_1_d.svg", transparent=True)

# %%
results_subset = all_results.query("task == 'lotka_volterra'")
with mpl.rc_context(fname="../../.matplotlibrc"):
    fig = fig_metric_mpl(results_subset, metric="C2ST", task_name="Lotka Volterra", title=False, xlabel=False)
    plt.savefig("../svg/panel_appendix_1_e.svg", transparent=True)

# %%
results_subset = all_results.query("task == 'bernoulli_glm'")
with mpl.rc_context(fname="../../.matplotlibrc"):
    fig = fig_metric_mpl(results_subset, metric="C2ST", task_name="Bernoulli GLM", title=False, xlabel=True)
    plt.savefig("../svg/panel_appendix_1_f.svg", transparent=True)

# %%
results_subset = all_results.query("task == 'gaussian_linear'")
with mpl.rc_context(fname="../../.matplotlibrc"):
    fig = fig_diagnostic(results_subset, metric="C2ST", task_name="Gaussian Linear", title=True, xlabel=False, legend=True)
    plt.savefig("../svg/panel_appendix_1_a2.svg", transparent=True)

# %%
results_subset = all_results.query("task == 'slcp'")
with mpl.rc_context(fname="../../.matplotlibrc"):
    fig = fig_diagnostic(results_subset, metric="C2ST", task_name="SLCP", title=True, xlabel=False)
    plt.savefig("../svg/panel_appendix_1_b2.svg", transparent=True)

# %%
results_subset = all_results.query("task == 'sir'")
with mpl.rc_context(fname="../../.matplotlibrc"):
    fig = fig_diagnostic(results_subset, metric="C2ST", task_name="SLCP", title=True, xlabel=False)
    plt.savefig("../svg/panel_appendix_1_c2.svg", transparent=True)

# %%
results_subset = all_results.query("task == 'two_moons'")
with mpl.rc_context(fname="../../.matplotlibrc"):
    fig = fig_diagnostic(results_subset, metric="C2ST", task_name="SLCP", title=True, xlabel=False, ylabel=False)
    plt.savefig("../svg/panel_appendix_1_d2.svg", transparent=True)

# %%
results_subset = all_results.query("task == 'lotka_volterra' & (num_simulations == 1000 | num_simulations == 10000 | num_simulations == 100000)")
with mpl.rc_context(fname="../../.matplotlibrc"):
    fig = fig_diagnostic(results_subset, metric="C2ST", task_name="SLCP", title=True, xlabel=False)
    plt.savefig("../svg/panel_appendix_1_e2.svg", transparent=True)

# %%
results_subset = all_results.query("task == 'bernoulli_glm'")
with mpl.rc_context(fname="../../.matplotlibrc"):
    fig = fig_diagnostic(results_subset, metric="C2ST", task_name="SLCP", title=True, xlabel=True)
    plt.savefig("../svg/panel_appendix_1_f2.svg", transparent=True)

# %%
import time
import IPython.display as IPd

def svg(img):
    IPd.display(IPd.HTML('<img src="{}" / >'.format(img, time.time())))

# %%
from svgutils.compose import *

# > Inkscape pixel is 1/90 of an inch, other software usually uses 1/72.
# > http://www.inkscapeforum.com/viewtopic.php?f=6&t=5964
svg_scale = 1.25  # set this to 1.25 for Inkscape, 1.0 otherwise

# Panel letters in Helvetica Neue, 12pt, Medium
kwargs_text = {'size': '12pt', 'font': 'Arial', 'weight': '800'}
kwargs_consistent = {'size': '10pt', 'font': 'Arial', 'weight': '500', 'color': '#AF99EF'}
kwargs_consistent1 = {'size': '10pt', 'font': 'Arial', 'weight': '500', 'color': '#9E7DD5'}
kwargs_inconsistent = {'size': '10pt', 'font': 'Arial', 'weight': '500', 'color': '#AF99EF'}
kwargs_text8pt = {'size': '7.7pt', 'font': 'Arial'}

f = Figure("15.7cm", "14.9cm",

    Panel(
          SVG("../svg/panel_appendix_1_a.svg").scale(svg_scale).move(0, 0),
        Text("Gaussian Linear", 280, -.0, **kwargs_text8pt),
    ).move(-5, 30),
    Panel(
          SVG("../svg/panel_appendix_1_b.svg").scale(svg_scale).move(0, 0),
        Text("SLCP", 300, -0.0, **kwargs_text8pt),
    ).move(-5,120),
    Panel(
          SVG("../svg/panel_appendix_1_c.svg").scale(svg_scale).move(0, 0),
        Text("SIR", 303, -0.0, **kwargs_text8pt),
    ).move(-5, 205),
    Panel(
          SVG("../svg/panel_appendix_1_d.svg").scale(svg_scale).move(0, 0),
        Text("Two Moons", 285, -0.0, **kwargs_text8pt),
    ).move(-5, 290),
    Panel(
          SVG("../svg/panel_appendix_1_e.svg").scale(svg_scale).move(0, 0),
        Text("Lotka Volterra", 281, -0.0, **kwargs_text8pt),
    ).move(-5, 375),
    Panel(
          SVG("../svg/panel_appendix_1_f.svg").scale(svg_scale).move(0, 0),
        Text("Bernoulli GLM", 280, -0.0, **kwargs_text8pt),
    ).move(-5, 460),

    Text("NPE", 60, 10.0, **kwargs_text8pt),
    Text("APT", 147, 10.0, **kwargs_text8pt),
    Text("TSNPE", 228, 10.0, **kwargs_text8pt),
    Text("Acceptance rate", 340, 10.0, **kwargs_text8pt),
    Text("GT samples in support", 480, 10.0, **kwargs_text8pt),
    
    Panel(
          SVG("../svg/panel_appendix_1_a2.svg").scale(svg_scale).move(0, 0),
    ).move(314, 5),
    Panel(
          SVG("../svg/panel_appendix_1_b2.svg").scale(svg_scale).move(0, 0),
    ).move(314, 120),
    Panel(
          SVG("../svg/panel_appendix_1_c2.svg").scale(svg_scale).move(0, 0),
    ).move(314, 205),
    Panel(
          SVG("../svg/panel_appendix_1_d2.svg").scale(svg_scale).move(0, 0),
    ).move(314, 290),
    Panel(
          SVG("../svg/panel_appendix_1_e2.svg").scale(svg_scale).move(0, 0),
    ).move(314, 375),
    Panel(
          SVG("../svg/panel_appendix_1_f2.svg").scale(svg_scale).move(0, 0),
    ).move(314, 460),
)

f.save("../fig/fig4_appendix1_point1percent.svg")
svg('../fig/fig4_appendix1_point1percent.svg')
# Out:
# <img src="../fig/fig4_appendix1_point1percent.svg" / >
